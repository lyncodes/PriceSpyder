# %%
import urllib3
import json
import time
from datetime import datetime

http = urllib3.PoolManager()
urllib3.disable_warnings()

class PriceCrawer:
    """"""

    def __init__(self, country: int = 37,
                 currency: int = 1,
                 payMethod: int = 0,
                 currPage: int = 1,
                 coinId: int = 1,
#                  different coinId for bitcoin or eth or others
                 tradeType: str = 'buy',
                 blockType: str = 'general',
                 online: int = 1):
        """

        :param country: default 37 for China
        :param currency: default 1 for CNY
        :param payMethod: does not matter
        :param currPage: default 1 for the information at the first page
        :param coinId: default 1 for BitCoin(for different purpose with other type of crypto)
        3 for ETH and so on .......
        :param tradeType: does not matter
        :param blockType: does not matter
        :param online: web tech, does not matter
        """
        self.country = country
        self.currency = currency
        self.payMethod = payMethod
        self.currPage = currPage
        self.coinId = coinId
        self.tradeType = tradeType
        self.blockType = blockType
        self.online = online

    def fetch_data(self):
        # this url was fetched by analysis the ajax
        self.url = 'https://otc-api.eiijo.cn/v1/data/trade-market?' + \
                   'country=' + \
                   str(self.country) + \
                   '&currency=' + \
                   str(self.currency) + \
                   '&payMethod=' + \
                   str(self.payMethod) + \
                   '&currPage=' + \
                   str(self.currPage) + \
                   '&coinId=' + \
                   str(self.coinId) + \
                   '&tradeType=' + \
                   str(self.tradeType) + \
                   '&blockType=' + \
                   str(self.blockType) + \
                   '&online=' + \
                   str(self.online)

        self.market_feed = http.request('GET', self.url)

        self.string_data = self.market_feed.data.decode()

    def show_data(self):
        self.market_data = json.loads(self.string_data)
        # covert string into json format
        for i in range(4):
            print(datetime.now())
            print('pirce_' + str(i), '---', self.market_data['data'][i]['price'])
            print(" ")

            
bitcoin_crawer = PriceCrawer(coinId=1)
while True:
    bitcoin_crawer.fetch_data()
    bitcoin_crawer.show_data()
    # fetch data every 3 seconds or as you want
    time.sleep(3)
# Out:
# 2019-03-27 03:17:55.203163
# pirce_0 --- 26780.0
#
# 2019-03-27 03:17:55.204161
# pirce_1 --- 26760.0
#
# 2019-03-27 03:17:55.204161
# pirce_2 --- 26755.13
#
# 2019-03-27 03:17:55.204161
# pirce_3 --- 26750.0
#
# 2019-03-27 03:17:58.318402
# pirce_0 --- 26780.0
#
# 2019-03-27 03:17:58.319402
# pirce_1 --- 26760.0
#
# 2019-03-27 03:17:58.319402
# pirce_2 --- 26755.13
#
# 2019-03-27 03:17:58.319402
# pirce_3 --- 26750.0
#
# 2019-03-27 03:18:01.425332
# pirce_0 --- 26780.0
#
# 2019-03-27 03:18:01.425332
# pirce_1 --- 26760.0
#
# 2019-03-27 03:18:01.425332
# pirce_2 --- 26755.13
#
# 2019-03-27 03:18:01.426330
# pirce_3 --- 26750.0
#
# 2019-03-27 03:18:04.527338
# pirce_0 --- 26780.0
#
# 2019-03-27 03:18:04.527338
# pirce_1 --- 26760.0
#
# 2019-03-27 03:18:04.528338
# pirce_2 --- 26755.13
#
# 2019-03-27 03:18:04.528338
# pirce_3 --- 26750.0
#
# 2019-03-27 03:18:07.628096
# pirce_0 --- 26780.0
#
# 2019-03-27 03:18:07.629094
# pirce_1 --- 26760.0
#
# 2019-03-27 03:18:07.629094
# pirce_2 --- 26755.13
#
# 2019-03-27 03:18:07.629094
# pirce_3 --- 26750.0
#
# 2019-03-27 03:18:10.738872
# pirce_0 --- 26780.0
#
# 2019-03-27 03:18:10.738872
# pirce_1 --- 26760.0
#
# 2019-03-27 03:18:10.738872
# pirce_2 --- 26755.13
#
# 2019-03-27 03:18:10.739875
# pirce_3 --- 26750.0
#
# 2019-03-27 03:18:13.837048
# pirce_0 --- 26780.0
#
# 2019-03-27 03:18:13.838048
# pirce_1 --- 26760.0
#
# 2019-03-27 03:18:13.838048
# pirce_2 --- 26755.13
#
# 2019-03-27 03:18:13.838048
# pirce_3 --- 26750.0
#
# 2019-03-27 03:18:16.937422
# pirce_0 --- 26780.0
#
# 2019-03-27 03:18:16.938421
# pirce_1 --- 26760.0
#
# 2019-03-27 03:18:16.938421
# pirce_2 --- 26755.13
#
# 2019-03-27 03:18:16.938421
# pirce_3 --- 26750.0
#
# 2019-03-27 03:18:20.037605
# pirce_0 --- 26780.0
#
# 2019-03-27 03:18:20.037605
# pirce_1 --- 26760.0
#
# 2019-03-27 03:18:20.037605
# pirce_2 --- 26755.13
#
# 2019-03-27 03:18:20.037605
# pirce_3 --- 26750.0
#
# 2019-03-27 03:18:23.138332
# pirce_0 --- 26780.0
#
# 2019-03-27 03:18:23.138332
# pirce_1 --- 26760.0
#
# 2019-03-27 03:18:23.138332
# pirce_2 --- 26755.13
#
# 2019-03-27 03:18:23.139328
# pirce_3 --- 26750.0
#
# 2019-03-27 03:18:26.391166
# pirce_0 --- 26780.0
#
# 2019-03-27 03:18:26.391166
# pirce_1 --- 26760.0
#
# 2019-03-27 03:18:26.391166
# pirce_2 --- 26753.18
#
# 2019-03-27 03:18:26.392166
# pirce_3 --- 26750.0
#
# 2019-03-27 03:18:29.518055
# pirce_0 --- 26780.0
#
# 2019-03-27 03:18:29.518055
# pirce_1 --- 26760.0
#
# 2019-03-27 03:18:29.518055
# pirce_2 --- 26753.18
#
# 2019-03-27 03:18:29.518055
# pirce_3 --- 26750.0
#
# 2019-03-27 03:18:32.629133
# pirce_0 --- 26780.0
#
# 2019-03-27 03:18:32.630120
# pirce_1 --- 26760.0
#
# 2019-03-27 03:18:32.630120
# pirce_2 --- 26753.18
#
# 2019-03-27 03:18:32.630120
# pirce_3 --- 26750.0
#
# 2019-03-27 03:18:35.748419
# pirce_0 --- 26780.0
#
# 2019-03-27 03:18:35.749419
# pirce_1 --- 26760.0
#
# 2019-03-27 03:18:35.749419
# pirce_2 --- 26753.18
#
# 2019-03-27 03:18:35.749419
# pirce_3 --- 26750.0
#
# 2019-03-27 03:18:38.854047
# pirce_0 --- 26780.0
#
# 2019-03-27 03:18:38.855047
# pirce_1 --- 26760.0
#
# 2019-03-27 03:18:38.855047
# pirce_2 --- 26753.18
#
# 2019-03-27 03:18:38.855047
# pirce_3 --- 26750.0
#
# 2019-03-27 03:18:41.963326
# pirce_0 --- 26780.0
#
# 2019-03-27 03:18:41.964324
# pirce_1 --- 26765.0
#
# 2019-03-27 03:18:41.964324
# pirce_2 --- 26760.0
#
# 2019-03-27 03:18:41.964324
# pirce_3 --- 26753.18
#
# 2019-03-27 03:18:45.064131
# pirce_0 --- 26780.0
#
# 2019-03-27 03:18:45.064131
# pirce_1 --- 26765.0
#
# 2019-03-27 03:18:45.065135
# pirce_2 --- 26760.0
#
# 2019-03-27 03:18:45.065135
# pirce_3 --- 26753.18
#
# 2019-03-27 03:18:48.170462
# pirce_0 --- 26780.0
#
# 2019-03-27 03:18:48.170462
# pirce_1 --- 26765.0
#
# 2019-03-27 03:18:48.170462
# pirce_2 --- 26760.0
#
# 2019-03-27 03:18:48.170462
# pirce_3 --- 26753.18
